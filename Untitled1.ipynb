# %%
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
root_dir = '../../data/200003076/output_resized_512_one_x0.8'
os.listdir(root_dir)
# Out:
# ['input_170_4.png',
#  'input_180_2.png',
#  'label_output_135_4.png',
#  'input_130_0.png',
#  'label_output_75_3.png',
#  'input_30_2.png',
#  'label_output_195_2.png',
#  'label_output_25_1.png',
#  'input_105_2.png',
#  'label_output_95_0.png',
#  'label_output_135_3.png',
#  'input_70_2.png',
#  'label_output_125_4.png',
#  'input_15_2.png',
#  'input_20_3.png',
#  'label_output_185_4.png',
#  'label_output_150_3.png',
#  'input_75_3.png',
#  'label_output_80_0.png',
#  'label_output_70_3.png',
#  'label_output_145_2.png',
#  'label_output_30_1.png',
#  'label_output_155_0.png',
#  'label_output_150_2.png',
#  'label_output_0_2.png',
#  'label_output_130_1.png',
#  'label_output_85_1.png',
#  'label_output_110_2.png',
#  'input_160_3.png',
#  'input_85_4.png',
#  'label_output_135_2.png',
#  'label_output_120_1.png',
#  'input_150_0.png',
#  'label_output_90_2.png',
#  'label_output_115_2.png',
#  'input_125_3.png',
#  'input_120_2.png',
#  'input_145_2.png',
# ...

# %%
image = Image.open(root_dir + '/label_output_90_0.png')

# %%
plt.figure(figsize = (10, 10))
plt.imshow(image)

# %%
np_image = np.array(image)
np_image = np_image[512:]

# %%
plt.imshow(np_image)

# %%
np_image[np_image < 127.5] = 0
np_image[np_image >= 127.5] = 1

# %%
plt.imshow(np_image)

# %%
np.max(np_image)
# Out:
# 255
